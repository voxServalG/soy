# %%
import json
import os
import numpy as np

# %%
with open("./soybean_dataset_a/ZS110001_19_G.json") as f:
    log = json.load(f)

# %%
polygons = []
for shape in log['shapes']:
    new_polygon = [shape['points']]
    polygons.append(new_polygon)

# %%
polygons
# Out:
# [[[[107.0, 132.5],
#    [95.0, 131.5],
#    [72.0, 121.5],
#    [69.0, 117.5],
#    [60.0, 111.5],
#    [44.5, 94.0],
#    [38.5, 82.0],
#    [36.5, 66.0],
#    [40.5, 53.0],
#    [49.0, 44.5],
#    [56.0, 41.5],
#    [83.0, 42.5],
#    [112.0, 59.5],
#    [130.5, 81.0],
#    [136.5, 98.0],
#    [136.5, 107.0],
#    [134.5, 113.0],
#    [127.0, 124.5],
#    [118.0, 129.5]]],
#  [[[224.0, 133.5],
#    [209.0, 133.5],
#    [197.0, 128.5],
#    [189.5, 121.0],
#    [180.5, 107.0],
#    [171.0, 100.5],
#    [168.0, 100.5],
#    [162.5, 93.0],
#    [161.5, 86.0],
#    [163.5, 72.0],
#    [166.5, 66.0],
#    [168.0, 64.5],
#    [169.5, 66.0],
#    [172.0, 76.5],
#    [173.5, 75.0],
#    [174.5, 66.0],
#    [179.5, 56.0],
#    [198.0, 45.5],
#    [207.0, 43.5],
#    [217.0, 43.5],
#    [227.0, 46.5],
#    [238.5, 55.0],
#    [243.5, 62.0],
#    [247.5, 72.0],
#    [249.5, 82.0],
#    [249.5, 95.0],
#    [246.5, 111.0],
#    [241.5, 122.0],
#    [232.0, 129.5]]],
#  [[[351.0, 135.5],
# ...
